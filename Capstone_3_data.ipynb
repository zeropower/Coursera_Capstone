# %% [markdown]
# ## Capstone Project - The Battle of Neighborhoods (Week 1)(Data section)

# %% [markdown]
# #### Use Taiwan's Latitude and Longitude information dataset.
#
# #### In order to use the Foursquare query, the township Chinese-English comparison data set was merged.
#
# #### The location category information of the two cities can be obtained by transferring the data from New Taipei City and Taipei City in the above data set to the Foursquare API.
#
# #### The  Foursquare Venue Category Hierarchy data is then obtained by the Foursquare API.
#
# #### By combining venue category information with  Foursquare Venue Category Hierarchy data, it is the data set to be analyzed.

# %% [markdown]
# ### 0. Import packages

# %%
import numpy as np 
import pandas as pd
import json
from geopy.geocoders import Nominatim
import requests 
from pandas import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %% [markdown]
# ### 1. Latitude and longitude of townships in Taiwan

# %% [markdown]
# - County, township, Chinese-English Excel file (Chinese Pinyin)
#     - Source [National Development Council] https://data.gov.tw/dataset/25489
#     - Download [Taiwan_postal.csv] https://quality.data.gov.tw/dq_download_csv.php?nid=25489&md5_url=ab48007db9f630e51fec0cb608e32d61
# - 3 yards postal code and administrative center latitude and longitude comparison table
#     - Source [Chunghwa Post Co., Ltd.] https://www.post.gov.tw/post/internet/Download/index.jsp?ID=220306
#     - Download [county_mapping.xls] https://www.post.gov.tw/post/download/county_h_10706.xls

# %% [markdown]
# #### 1-1 Loading Taiwan latitude and longitude data

# %%
ll_data = pd.read_csv('Taiwan_postal.csv')
ll_data.rename(columns={"_x0033_碼郵遞區號": "Postal code", "中心點經度": "Longitude", "中心點緯度": "Latitude"},inplace=True)
ll_data.drop(['TGOS_URL'],axis=1,inplace=True)
ll_data
# Out:
#        行政區名  Postal code   Longitude   Latitude
# 0    臺北市中正區          100  121.519884  25.032405
# 1    臺北市大同區          103  121.513042  25.063424
# 2    臺北市中山區          104  121.538160  25.069699
# 3    臺北市松山區          105  121.557588  25.059991
# 4    臺北市大安區          106  121.543445  25.026770
# ..      ...          ...         ...        ...
# 366  花蓮縣瑞穗鄉          978  121.407347  23.515612
# 367  花蓮縣萬榮鄉          979  121.318953  23.727726
# 368  花蓮縣玉里鎮          981  121.360448  23.371436
# 369  花蓮縣卓溪鄉          982  121.180422  23.390629
# 370  花蓮縣富里鄉          983  121.298049  23.196721
#
# [371 rows x 4 columns]

# %% [markdown]
# #### 1-2 Loading township Chinese-English data

# %%
map_data = pd.read_excel('county_mapping.xls', header=None)
map_data.columns = ['Postal code','行政區名','District name']
map_data
# Out:
#      Postal code    行政區名                     District name
# 0            100  臺北市中正區     Zhongzheng Dist., Taipei City
# 1            103  臺北市大同區         Datong Dist., Taipei City
# 2            104  臺北市中山區      Zhongshan Dist., Taipei City
# 3            105  臺北市松山區       Songshan Dist., Taipei City
# 4            106  臺北市大安區          Da’an Dist., Taipei City
# ..           ...     ...                               ...
# 366          978  花蓮縣瑞穗鄉   Ruisui Township, Hualien County
# 367          979  花蓮縣萬榮鄉  Wanrong Township, Hualien County
# 368          981  花蓮縣玉里鎮     Yuli Township, Hualien County
# 369          982  花蓮縣卓溪鄉   Zhuoxi Township, Hualien County
# 370          983  花蓮縣富里鄉     Fuli Township, Hualien County
#
# [371 rows x 3 columns]

# %% [markdown]
# #### **Notice: The administrative districts in the two datasets have different names, but those places are not habitable, so they can be ignored.**

# %%
diff = pd.concat([ll_data['行政區名'],map_data['行政區名']]).drop_duplicates(keep=False)
diff
# Out:
# 64     宜蘭縣釣魚臺列嶼
# 270    南海諸島東沙群島
# 271    南海諸島南沙群島
# 64          釣魚台
# 270     高雄市東沙群島
# 271     高雄市南沙群島
# Name: 行政區名, dtype: object

# %% [markdown]
# #### 1-3 Merge two dataset

# %%
taiwan_data = pd.merge(map_data, ll_data,on=['Postal code', '行政區名'])
taiwan_data
# Out:
#      Postal code    行政區名                     District name   Longitude  \
# 0            100  臺北市中正區     Zhongzheng Dist., Taipei City  121.519884
# 1            103  臺北市大同區         Datong Dist., Taipei City  121.513042
# 2            104  臺北市中山區      Zhongshan Dist., Taipei City  121.538160
# 3            105  臺北市松山區       Songshan Dist., Taipei City  121.557588
# 4            106  臺北市大安區          Da’an Dist., Taipei City  121.543445
# ..           ...     ...                               ...         ...
# 363          978  花蓮縣瑞穗鄉   Ruisui Township, Hualien County  121.407347
# 364          979  花蓮縣萬榮鄉  Wanrong Township, Hualien County  121.318953
# 365          981  花蓮縣玉里鎮     Yuli Township, Hualien County  121.360448
# 366          982  花蓮縣卓溪鄉   Zhuoxi Township, Hualien County  121.180422
# 367          983  花蓮縣富里鄉     Fuli Township, Hualien County  121.298049
#
#       Latitude
# 0    25.032405
# 1    25.063424
# 2    25.069699
# 3    25.059991
# 4    25.026770
# ..         ...
# 363  23.515612
# 364  23.727726
# 365  23.371436
# 366  23.390629
# 367  23.196721
#
# [368 rows x 5 columns]

# %% [markdown]
# ### 2. Venue categories in New Taipei City

# %% [markdown]
# #### 2-1 Using Taipei City and New Taipei City data

# %%
city_data = taiwan_data[taiwan_data['District name'].str.contains("Taipei City")]
city_data
# Out:
#     Postal code    行政區名                     District name   Longitude  \
# 0           100  臺北市中正區     Zhongzheng Dist., Taipei City  121.519884
# 1           103  臺北市大同區         Datong Dist., Taipei City  121.513042
# 2           104  臺北市中山區      Zhongshan Dist., Taipei City  121.538160
# 3           105  臺北市松山區       Songshan Dist., Taipei City  121.557588
# 4           106  臺北市大安區          Da’an Dist., Taipei City  121.543445
# 5           108  臺北市萬華區         Wanhua Dist., Taipei City  121.497986
# 6           110  臺北市信義區          Xinyi Dist., Taipei City  121.571670
# 7           111  臺北市士林區         Shilin Dist., Taipei City  121.550847
# 8           112  臺北市北投區         Beitou Dist., Taipei City  121.517799
# 9           114  臺北市內湖區          Neihu Dist., Taipei City  121.592383
# 10          115  臺北市南港區        Nangang Dist., Taipei City  121.609757
# 11          116  臺北市文山區        Wenshan Dist., Taipei City  121.573608
# 19          207  新北市萬里區      Wanli Dist., New Taipei City  121.643931
# 20          208  新北市金山區    Jinshan Dist., New Taipei City  121.605264
# 25          220  新北市板橋區    Banqiao Dist., New Taipei City  121.457968
# 26          221  新北市汐止區      Xizhi Dist., New Taipei City  121.654699
# 27          222  新北市深坑區   Shenkeng Dist., New Taipei City  121.620062
# 28          223  新北市石碇區    Shiding Dist., New Taipei City  121.647228
# 29          224  新北市瑞芳區    Ruifang Dist., New Taipei City  121.823202
# 30          226  新北市平溪區     Pingxi Dist., New Taipei City  121.757882
# 31          227  新北市雙溪區   Shuangxi Dist., New Taipei City  121.832982
# 32          228  新北市貢寮區   Gongliao Dist., New Taipei City  121.918247
# 33          231  新北市新店區    Xindian Dist., New Taipei City  121.531656
# 34          232  新北市坪林區    Pinglin Dist., New Taipei City  121.724223
# 35          233  新北市烏來區      Wulai Dist., New Taipei City  121.541481
# 36          234  新北市永和區     Yonghe Dist., New Taipei City  121.516745
# 37          235  新北市中和區    Zhonghe Dist., New Taipei City  121.493674
# 38          236  新北市土城區    Tucheng Dist., New Taipei City  121.445737
# 39          237  新北市三峽區     Sanxia Dist., New Taipei City  121.416309
# 40          238  新北市樹林區     Shulin Dist., New Taipei City  121.401034
# 41          239  新北市鶯歌區     Yingge Dist., New Taipei City  121.346627
# 42          241  新北市三重區   Sanchong Dist., New Taipei City  121.487098
# 43          242  新北市新莊區  Xinzhuang Dist., New Taipei City  121.436753
# 44          243  新北市泰山區    Taishan Dist., New Taipei City  121.416278
# 45          244  新北市林口區     Linkou Dist., New Taipei City  121.352724
# 46          247  新北市蘆洲區     Luzhou Dist., New Taipei City  121.471246
# 47          248  新北市五股區       Wugu Dist., New Taipei City  121.433214
# 48          249  新北市八里區       Bali Dist., New Taipei City  121.413836
# 49          251  新北市淡水區     Tamsui Dist., New Taipei City  121.463904
# 50          252  新北市三芝區     Sanzhi Dist., New Taipei City  121.515558
# 51          253  新北市石門區     Shimen Dist., New Taipei City  121.569276
#
#      Latitude
# 0   25.032405
# 1   25.063424
# 2   25.069699
# 3   25.059991
# 4   25.026770
# 5   25.028590
# 6   25.030621
# 7   25.125467
# 8   25.148068
# 9   25.083706
# 10  25.036009
# 11  24.988579
# 19  25.175725
# 20  25.217146
# 25  25.011865
# 26  25.073313
# 27  24.997675
# 28  24.947141
# 29  25.098129
# 30  25.026071
# 31  24.996984
# 32  25.024856
# 33  24.930390
# 34  24.910971
# 35  24.788243
# 36  25.008102
# 37  24.990880
# 38  24.964251
# 39  24.882098
# 40  24.979706
# 41  24.956626
# 42  25.062817
# 43  25.035830
# 44  25.055498
# 45  25.100087
# 46  25.089272
# 47  25.096147
# 48  25.138128
# 49  25.189076
# 50  25.231599
# 51  25.265181

# %% [markdown]
# #### 2-2 Foursquare Settings

# %%
CLIENT_ID = 'M143ASAFEMECNO05TR44UEDIRA2CL4X0VPXJZCGX1QCJF3ZF' # your Foursquare ID
CLIENT_SECRET = 'BCELZQVSDCZ0DZZXR14FZA5SYMFGT21ITWK0T4FMQJ13VEFQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 
radius = 5000

# %% [markdown]
# #### 2-3 Functions for getting information on venues

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['District', 
                  'District Latitude', 
                  'District Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### 2-4 Get information on venues in Taipei and New Taipei City

# %%
taipei_categories = getNearbyVenues(names=city_data['District name'],
                                   latitudes=city_data['Latitude'],
                                   longitudes=city_data['Longitude']
                                  )
taipei_categories
# Out:
#                           District  District Latitude  District Longitude  \
# 0    Zhongzheng Dist., Taipei City          25.032405          121.519884
# 1    Zhongzheng Dist., Taipei City          25.032405          121.519884
# 2    Zhongzheng Dist., Taipei City          25.032405          121.519884
# 3    Zhongzheng Dist., Taipei City          25.032405          121.519884
# 4    Zhongzheng Dist., Taipei City          25.032405          121.519884
# ..                             ...                ...                 ...
# 332  Luzhou Dist., New Taipei City          25.089272          121.471246
# 333  Luzhou Dist., New Taipei City          25.089272          121.471246
# 334  Luzhou Dist., New Taipei City          25.089272          121.471246
# 335  Luzhou Dist., New Taipei City          25.089272          121.471246
# 336  Sanzhi Dist., New Taipei City          25.231599          121.515558
#
#                                              Venue  Venue Latitude  \
# 0                 Kinfen Braised Pork Rice (金峰魯肉飯)       25.032194
# 1                                      臻味赤肉胡椒餅 烤地瓜       25.033022
# 2            Chiang Kai-Shek Memorial Hall (中正紀念堂)       25.034555
# 3                                             虎記商行       25.031744
# 4                         National Theater (國家戲劇院)       25.035197
# ..                                             ...             ...
# 332                           星巴克 STARBUCKS 蘆洲三民門市       25.087397
# 333                                肯德基 KFC（蘆洲三民餐廳）       25.087043
# 334                               FamilyMart_蘆洲民族店       25.091190
# 335  捷運三民高中站 MRT Sanmin Senior High School Station       25.085741
# 336                                          八連溪水車       25.233907
#
#      Venue Longitude        Venue Category
# 0         121.518534  Taiwanese Restaurant
# 1         121.518246                Bakery
# 2         121.521835   Monument / Landmark
# 3         121.519284                  Café
# 4         121.518188               Theater
# ..               ...                   ...
# 332       121.471177           Coffee Shop
# 333       121.471592   Fried Chicken Joint
# 334       121.474040         Deli / Bodega
# 335       121.473080         Metro Station
# 336       121.514404                  Park
#
# [337 rows x 7 columns]

# %% [markdown]
# #### 2-5 See how many venues are in each area

# %%
taipei_categories['District'].value_counts()
# Out:
# Songshan Dist., Taipei City         57
# Da’an Dist., Taipei City            40
# Banqiao Dist., New Taipei City      39
# Zhongzheng Dist., Taipei City       33
# Wenshan Dist., Taipei City          23
# Neihu Dist., Taipei City            23
# Datong Dist., Taipei City           21
# Yonghe Dist., New Taipei City       20
# Xinyi Dist., Taipei City            19
# Zhongshan Dist., Taipei City        13
# Xinzhuang Dist., New Taipei City     8
# Zhonghe Dist., New Taipei City       7
# Nangang Dist., Taipei City           5
# Wanhua Dist., Taipei City            5
# Luzhou Dist., New Taipei City        4
# Sanchong Dist., New Taipei City      4
# Shilin Dist., Taipei City            3
# Jinshan Dist., New Taipei City       3
# Tucheng Dist., New Taipei City       2
# Shenkeng Dist., New Taipei City      2
# Sanzhi Dist., New Taipei City        1
# Wanli Dist., New Taipei City         1
# Shuangxi Dist., New Taipei City      1
# Xizhi Dist., New Taipei City         1
# Yingge Dist., New Taipei City        1
# Shiding Dist., New Taipei City       1
# Name: District, dtype: int64

# %% [markdown]
# #### 2-6 Areas with too little data cannot be analyzed, so remove them

# %%
taipei_categories = taipei_categories.groupby('District').filter(lambda x : len(x)>=10)
taipei_categories
# Out:
#                           District  District Latitude  District Longitude  \
# 0    Zhongzheng Dist., Taipei City          25.032405          121.519884
# 1    Zhongzheng Dist., Taipei City          25.032405          121.519884
# 2    Zhongzheng Dist., Taipei City          25.032405          121.519884
# 3    Zhongzheng Dist., Taipei City          25.032405          121.519884
# 4    Zhongzheng Dist., Taipei City          25.032405          121.519884
# ..                             ...                ...                 ...
# 305  Yonghe Dist., New Taipei City          25.008102          121.516745
# 306  Yonghe Dist., New Taipei City          25.008102          121.516745
# 307  Yonghe Dist., New Taipei City          25.008102          121.516745
# 308  Yonghe Dist., New Taipei City          25.008102          121.516745
# 309  Yonghe Dist., New Taipei City          25.008102          121.516745
#
#                                      Venue  Venue Latitude  Venue Longitude  \
# 0         Kinfen Braised Pork Rice (金峰魯肉飯)       25.032194       121.518534
# 1                              臻味赤肉胡椒餅 烤地瓜       25.033022       121.518246
# 2    Chiang Kai-Shek Memorial Hall (中正紀念堂)       25.034555       121.521835
# 3                                     虎記商行       25.031744       121.519284
# 4                 National Theater (國家戲劇院)       25.035197       121.518188
# ..                                     ...             ...              ...
# 305                                 50嵐樂華店       25.007965       121.513975
# 306                                   阿里小廚       25.008220       121.513679
# 307                                 台南蔡虱目魚       25.004513       121.517750
# 308                                  龜叟什錦麵       25.006000       121.513205
# 309                      Piemonte 派夢地手工烘焙坊       25.012129       121.515202
#
#            Venue Category
# 0    Taiwanese Restaurant
# 1                  Bakery
# 2     Monument / Landmark
# 3                    Café
# 4                 Theater
# ..                    ...
# 305       Bubble Tea Shop
# 306            Steakhouse
# 307  Taiwanese Restaurant
# 308          Noodle House
# 309                Bakery
#
# [288 rows x 7 columns]

# %% [markdown]
# ### 3. Foursquare category data

# %% [markdown]
# #### 3-1 Get json data

# %%
url = 'https://api.foursquare.com/v2/venues/categories?&client_id={}&client_secret={}&v={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET,
            VERSION)           
# make the GET request
json_categories = requests.get(url).json()

# %% [markdown]
# #### 3-2 Flatten the json data and get the top parent category of all category

# %%
categories = json_normalize(json_categories['response']['categories'])
categories['1st_categories'] = ""

for idx in range(0,len(categories)):
    s1 = json_normalize(json_categories['response']['categories'][idx]['categories'])
    for idx2 in range(0,len(s1)):
        s2 = json_normalize(json_categories['response']['categories'][idx]['categories'][idx2]['categories'])
        if(json_categories['response']['categories'][idx]['categories'][idx2]['categories']!=[]):
            for idx3 in range(0,len(s2)):
                s3 = json_normalize(json_categories['response']['categories'][idx]['categories'][idx2]['categories'][idx3]['categories'])
                if(json_categories['response']['categories'][idx]['categories'][idx2]['categories'][idx3]['categories']!=[]):
                    for idx4 in range(0,len(s3)):
                        s4 = json_normalize(json_categories['response']['categories'][idx]['categories'][idx2]['categories'][idx3]['categories'][idx4]['categories'])
                        s4['1st_categories'] = json_categories['response']['categories'][idx]['name']
                        categories = categories.append(s4)
                s3['1st_categories'] = json_categories['response']['categories'][idx]['name']   
                categories = categories.append(s3)
        s2['1st_categories'] = json_categories['response']['categories'][idx]['name']
        categories = categories.append(s2)
    s1['1st_categories'] = json_categories['response']['categories'][idx]['name']
    categories = categories.append(s1)

categories = categories.drop(['id', 'pluralName','shortName','categories','icon.prefix','icon.suffix'], axis=1).reset_index(drop=True)

# %% [markdown]
# #### 3-3 Merge two dataset

# %%
taipei_merge = pd.merge(taipei_categories, categories, left_on = 'Venue Category', right_on = 'name')
taipei_merge.drop(['name'],axis=1)
# Out:
#                            District  District Latitude  District Longitude  \
# 0     Zhongzheng Dist., Taipei City          25.032405          121.519884
# 1         Datong Dist., Taipei City          25.063424          121.513042
# 2         Datong Dist., Taipei City          25.063424          121.513042
# 3         Datong Dist., Taipei City          25.063424          121.513042
# 4         Datong Dist., Taipei City          25.063424          121.513042
# ..                              ...                ...                 ...
# 283  Banqiao Dist., New Taipei City          25.011865          121.457968
# 284  Banqiao Dist., New Taipei City          25.011865          121.457968
# 285  Banqiao Dist., New Taipei City          25.011865          121.457968
# 286   Yonghe Dist., New Taipei City          25.008102          121.516745
# 287   Yonghe Dist., New Taipei City          25.008102          121.516745
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 0    Kinfen Braised Pork Rice (金峰魯肉飯)       25.032194       121.518534
# 1                           大橋頭老牌筒仔米糕       25.064753       121.511127
# 2                              旗魚新竹米粉       25.067305       121.511002
# 3                               昌吉豬血湯       25.065864       121.516489
# 4                             珠記大橋頭油飯       25.062899       121.514732
# ..                                ...             ...              ...
# 283                      HiMall麗寶百貨廣場       25.012792       121.462615
# 284                  Bon Appétit (朋派)       25.011638       121.462537
# 285           Hilton Executive Lounge       25.011340       121.462566
# 286                            太原養生會館       25.006819       121.513094
# 287                             九乘九文具       25.011016       121.514802
#
#                     Venue Category  1st_categories
# 0             Taiwanese Restaurant            Food
# 1             Taiwanese Restaurant            Food
# 2             Taiwanese Restaurant            Food
# 3             Taiwanese Restaurant            Food
# 4             Taiwanese Restaurant            Food
# ..                             ...             ...
# 283                  Shopping Mall  Shop & Service
# 284                         Buffet            Food
# 285                         Lounge  Nightlife Spot
# 286                 Massage Studio  Shop & Service
# 287  Paper / Office Supplies Store  Shop & Service
#
# [288 rows x 8 columns]

# %% [markdown]
# #### 3-4 See the number of different types of places

# %%
taipei_merge['1st_categories'].value_counts()
# Out:
# Food                           196
# Shop & Service                  48
# Outdoors & Recreation           20
# Arts & Entertainment            11
# Nightlife Spot                   8
# Travel & Transport               3
# Professional & Other Places      2
# Name: 1st_categories, dtype: int64

# %% [markdown]
# #### 3-5 The number of venues is too small to analyze, so remove them

# %%
taipei_merge = taipei_merge.groupby('1st_categories').filter(lambda x : len(x)>=10)
taipei_merge
# Out:
#                            District  District Latitude  District Longitude  \
# 0     Zhongzheng Dist., Taipei City          25.032405          121.519884
# 1         Datong Dist., Taipei City          25.063424          121.513042
# 2         Datong Dist., Taipei City          25.063424          121.513042
# 3         Datong Dist., Taipei City          25.063424          121.513042
# 4         Datong Dist., Taipei City          25.063424          121.513042
# ..                              ...                ...                 ...
# 282  Banqiao Dist., New Taipei City          25.011865          121.457968
# 283  Banqiao Dist., New Taipei City          25.011865          121.457968
# 284  Banqiao Dist., New Taipei City          25.011865          121.457968
# 286   Yonghe Dist., New Taipei City          25.008102          121.516745
# 287   Yonghe Dist., New Taipei City          25.008102          121.516745
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 0    Kinfen Braised Pork Rice (金峰魯肉飯)       25.032194       121.518534
# 1                           大橋頭老牌筒仔米糕       25.064753       121.511127
# 2                              旗魚新竹米粉       25.067305       121.511002
# 3                               昌吉豬血湯       25.065864       121.516489
# 4                             珠記大橋頭油飯       25.062899       121.514732
# ..                                ...             ...              ...
# 282                      AWHILE. 外兒小館       25.014028       121.460790
# 283                      HiMall麗寶百貨廣場       25.012792       121.462615
# 284                  Bon Appétit (朋派)       25.011638       121.462537
# 286                            太原養生會館       25.006819       121.513094
# 287                             九乘九文具       25.011016       121.514802
#
#                     Venue Category                           name  \
# 0             Taiwanese Restaurant           Taiwanese Restaurant
# 1             Taiwanese Restaurant           Taiwanese Restaurant
# 2             Taiwanese Restaurant           Taiwanese Restaurant
# 3             Taiwanese Restaurant           Taiwanese Restaurant
# 4             Taiwanese Restaurant           Taiwanese Restaurant
# ..                             ...                            ...
# 282                  Deli / Bodega                  Deli / Bodega
# 283                  Shopping Mall                  Shopping Mall
# 284                         Buffet                         Buffet
# 286                 Massage Studio                 Massage Studio
# 287  Paper / Office Supplies Store  Paper / Office Supplies Store
#
#      1st_categories
# 0              Food
# 1              Food
# 2              Food
# 3              Food
# 4              Food
# ..              ...
# 282            Food
# 283  Shop & Service
# 284            Food
# 286  Shop & Service
# 287  Shop & Service
#
# [275 rows x 9 columns]

# %%
taipei_merge.to_csv('taipei_geo.csv')
